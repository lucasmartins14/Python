# %%
import pyautogui

# %%
import pyperclip

# %%
import pandas as pd

# %%
pyautogui.PAUSE = 1

# abrir o google chorme
pyautogui.press("winleft")
pyautogui.write("chrome")
pyautogui.press("enter")
pyautogui.alert("Vai começar, aperta OK para iniciar")

# colar link "drive"'
link = "https://drive.google.com/drive/u/0/mobile/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# apontar clicks
time.sleep(15)

pyautogui.click(x=150, y=377, clicks=1)

time.sleep(7)

pyautogui.click(x=92, y=370)


time.sleep(10)

# %%
# ler excel com pandas
df = pd.read_excel(r'C:\Users\lucas.alexandre\Downloads\Vendas - Dez.xlsx')

display(df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# criar os indicadores
faturamento = df['Valor Final'].sum()
qtde_produtos = df['Quantidade'].sum()

# %%
# abrir google chrome

pyautogui.PAUSE = 1

pyautogui.press("winleft")
pyautogui.write("chrome")
pyautogui.press("enter")


# abrir link "hotmail"
link = "https://outlook.live.com/mail/0/inbox"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")


time.sleep(15)

# clicar  em "Nova mensagem"
pyautogui.click(x=155, y=203, clicks=1) 

time.sleep(7)

# clicar no "Destinatario"
pyautogui.click(x=375, y=271)

time.sleep(3)

# escrever destinatário
pyautogui.write('lucasalexanddre@hotmail.com')

time.sleep(5)

# clicar no "Assunto"
pyautogui.click(x=305, y=324)

# criar variável para o assunto e colar
assunto = 'Relatorio de Vendas de Ontem'

pyperclip.copy(assunto)

pyautogui.hotkey('ctrl', 'v')


time.sleep(5)

# passar para corpo do e-mail
pyautogui.press('tab')

# descrever assunto do corpo do e-mail trazendo os indicadores criados anteriormente
texto = f"""

Prezados, bom dia

O fatauramento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {qtde_produtos:,}

Abs

Lucas Martins """

# colar e enviar
pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')

time.sleep(5)
pyautogui.hotkey('ctrl', 'enter')
